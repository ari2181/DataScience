# %% [markdown]
# # Model Selection - Option 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn import preprocessing
import sklearn.metrics as metrics

# %%
df_train = pd.read_pickle(r'C:\DataScience\PROJECT_AFIMILK\Data\Flat_File_for_cleansing\df_train_42.p')
df_val = pd.read_pickle(r'C:\DataScience\PROJECT_AFIMILK\Data\Flat_File_for_cleansing\df_validation_42.p')

# %%
df_train.head()
# Out:
#                        DailyRestBout  DailyRestTime_t1  Term  PrevDryDays  \
# FarmCowID CalvingDate
# 974431    2019-01-25            15.0               280  48.0         75.0
# 124852    2018-12-02            -1.0               419  38.0          0.0
# 124740    2021-05-03            10.0                67  47.0         56.0
# 124841    2019-01-28             5.0                28  50.0          0.0
# 325688    2020-02-15            -1.0                 0  59.0         66.0
#
#                        WeightCalv  DailyRestTime  DailyProdRate  \
# FarmCowID CalvingDate
# 974431    2019-01-25       410.25          288.0          484.0
# 124852    2018-12-02         0.00           -1.0          432.0
# 124740    2021-05-03         0.00          348.0         1231.0
# 124841    2019-01-28         0.00          414.0          735.0
# 325688    2020-02-15         0.00           -1.0            0.0
#
#                        DailyRestPerBout_t7  DailyMilkingTime_t7  \
# FarmCowID CalvingDate
# 974431    2019-01-25                    30                  -37
# 124852    2018-12-02                    -1                  -22
# 124740    2021-05-03                    -7                  -35
# 124841    2019-01-28                   -18                    4
# 325688    2020-02-15                     0                   -4
#
#                        AccumulateECMFromDay4_KG_t6  ...  \
# FarmCowID CalvingDate                               ...
# 974431    2019-01-25                      39.12130  ...
# 124852    2018-12-02                      26.02424  ...
# 124740    2021-05-03                      54.69560  ...
# 124841    2019-01-28                      26.10660  ...
# 325688    2020-02-15                      35.66030  ...
#
#                        DailyHeatIndicator_t2i  DailyHeatIndicator_t4i  \
# FarmCowID CalvingDate
# 974431    2019-01-25                    -28.0                    14.0
# 124852    2018-12-02                     -3.5                     3.5
# 124740    2021-05-03                    -14.5                     0.5
# 124841    2019-01-28                      7.5                     1.5
# 325688    2020-02-15                      0.0                     0.0
#
#                        DailyRestTime_t2i  DailyRestPerBout_t6i  \
# FarmCowID CalvingDate
# 974431    2019-01-25               -70.0                  -9.5
# 124852    2018-12-02               108.5                  -4.0
# 124740    2021-05-03                34.0                  -2.5
# 124841    2019-01-28               -31.0                   4.0
# 325688    2020-02-15                 0.0                   0.0
#
#                        DailyRestTime_t6i  FarmCode_32  PPUD_0.0  \
# FarmCowID CalvingDate
# 974431    2019-01-25                -8.0          0.0       0.0
# 124852    2018-12-02                -6.5          0.0       0.0
# 124740    2021-05-03                 1.0          0.0       1.0
# 124841    2019-01-28               -23.5          0.0       0.0
# 325688    2020-02-15                 0.0          1.0       1.0
#
#                        DailyRestBout_t3_cat_9.0  CurMet_t7_t30  split
# FarmCowID CalvingDate
# 974431    2019-01-25                        0.0            1.0  train
# 124852    2018-12-02                        0.0            1.0  train
# 124740    2021-05-03                        0.0            0.0  train
# 124841    2019-01-28                        0.0            1.0  train
# 325688    2020-02-15                        0.0            0.0  train
#
# [5 rows x 43 columns]

# %%
df_train = df_train.drop(columns='split')

# %%
df_val.head()
# Out:
#                        DailyRestBout  DailyRestTime_t1  Term  PrevDryDays  \
# FarmCowID CalvingDate
# 975240    2019-07-10            11.0                -9  56.0          0.0
# 325614    2018-11-19            -1.0                 0  55.0          0.0
# 124166    2021-01-27            -1.0                 0  50.0          0.0
# 1241374   2017-11-29            -1.0                 0  46.0         58.0
# 974736    2016-12-21             9.0               -75  38.0          0.0
#
#                        WeightCalv  DailyRestTime  DailyProdRate  \
# FarmCowID CalvingDate
# 975240    2019-07-10      561.750          523.0          552.0
# 325614    2018-11-19      552.249           -1.0          934.0
# 124166    2021-01-27        0.000           -1.0          271.0
# 1241374   2017-11-29        0.000           -1.0          497.0
# 974736    2016-12-21      581.750          670.0          690.0
#
#                        DailyRestPerBout_t7  DailyMilkingTime_t7  \
# FarmCowID CalvingDate
# 975240    2019-07-10                    12                    7
# 325614    2018-11-19                     0                  -80
# 124166    2021-01-27                   -64                  209
# 1241374   2017-11-29                     0                  390
# 974736    2016-12-21                     1                   21
#
#                        AccumulateECMFromDay4_KG_t6  ...  \
# FarmCowID CalvingDate                               ...
# 975240    2019-07-10                      25.92484  ...
# 325614    2018-11-19                      34.41530  ...
# 124166    2021-01-27                      25.68370  ...
# 1241374   2017-11-29                      38.69800  ...
# 974736    2016-12-21                      26.48264  ...
#
#                        DailyHeatIndicator_t2i  DailyHeatIndicator_t4i  \
# FarmCowID CalvingDate
# 975240    2019-07-10                      5.0                     8.0
# 325614    2018-11-19                      0.0                     0.0
# 124166    2021-01-27                    -11.5                   -10.5
# 1241374   2017-11-29                      0.0                     0.0
# 974736    2016-12-21                      0.0                     6.5
#
#                        DailyRestTime_t2i  DailyRestPerBout_t6i  \
# FarmCowID CalvingDate
# 975240    2019-07-10                -4.0                  -6.0
# 325614    2018-11-19                 0.0                   0.0
# 124166    2021-01-27                 0.0                   4.0
# 1241374   2017-11-29                 0.0                   0.0
# 974736    2016-12-21                67.0                  -7.0
#
#                        DailyRestTime_t6i  FarmCode_32  PPUD_0.0  \
# FarmCowID CalvingDate
# 975240    2019-07-10               -18.0          0.0       1.0
# 325614    2018-11-19                 0.0          1.0       1.0
# 124166    2021-01-27               -12.5          0.0       1.0
# 1241374   2017-11-29                 0.0          0.0       1.0
# 974736    2016-12-21               -43.0          0.0       0.0
#
#                        DailyRestBout_t3_cat_9.0  CurMet_t7_t30  split
# FarmCowID CalvingDate
# 975240    2019-07-10                        0.0            0.0   test
# 325614    2018-11-19                        0.0            0.0   test
# 124166    2021-01-27                        0.0            1.0   test
# 1241374   2017-11-29                        0.0            0.0   test
# 974736    2016-12-21                        0.0            1.0   test
#
# [5 rows x 43 columns]

# %%
df_val = df_val.drop(columns='split')

# %%
X_train = df_train.drop(columns= 'CurMet_t7_t30')
y_train = df_train['CurMet_t7_t30'].astype('category')

print(X_train.shape)
print(y_train.shape)
# Out:
# (2140, 41)
# (2140,)

# %%
X_val = df_val.drop(columns= 'CurMet_t7_t30')
y_val = df_val['CurMet_t7_t30'].astype('category')

print(X_val.shape)
print(y_val.shape)
# Out:
# (536, 41)
# (536,)

# %%
def classificationMetrics(y, yhat):
    prf1 = metrics.precision_recall_fscore_support(y,yhat)
    res = {'Accuracy': metrics.accuracy_score(y,yhat),
           'Precision':prf1[0][1],
           'Recall': prf1[1][1],
           'f1-score': prf1[2][1],
           'Log-loss': metrics.log_loss(y,yhat),
           'AUC': metrics.roc_auc_score(y,yhat)
          }
    return res

models_list = pd.DataFrame()

# %% [markdown]
# ## Logistic Regration

# %%
## Normalized the variables
scaler = preprocessing.StandardScaler().fit(X_train)
X_scaled = scaler.transform(X_train)
##
scaler_val = preprocessing.StandardScaler().fit(X_val)
X_scaled_val = scaler.transform(X_val)

# %%
mod1 = LogisticRegression(max_iter= 1000, random_state= 1).fit(X_scaled,y_train)

# %%
pred_train1 = mod1.predict(X_scaled)
pd.crosstab(y_train,pred_train1, colnames= ['pred_rtain1'])
# Out:
# pred_rtain1     0.0  1.0
# CurMet_t7_t30
# 0.0            1468   19
# 1.0             134  519

# %%
pred_val1 = mod1.predict(X_scaled_val)
pd.crosstab(y_val, pred_val1, colnames= ['pred_val1'])
# Out:
# pred_val1      0.0  1.0
# CurMet_t7_t30
# 0.0            365   11
# 1.0             38  122

# %%
model_dict = {'model': "Logistic Regression"}
dataset_dict = {'dataset': "Train"}
models_list = models_list.append({**dataset_dict, **model_dict, **classificationMetrics(y_val, pred_val1)}, ignore_index=True)
##
model_dict = {'model': "Logistic Regression"}
dataset_dict = {'dataset': "Validation"}
models_list = models_list.append({**dataset_dict, **model_dict, **classificationMetrics(y_train, pred_train1)}, ignore_index=True)
##
models_list
# Out:
#         AUC  Accuracy  Log-loss  Precision    Recall     dataset  f1-score  \
# 0  0.866622  0.908582  3.157479   0.917293  0.762500       Train  0.832765
# 1  0.891008  0.928505  2.469368   0.964684  0.794793  Validation  0.871537
#
#                  model
# 0  Logistic Regression
# 1  Logistic Regression

# %% [markdown]
# ## Decision Tree

# %%
mod2 = DecisionTreeClassifier(random_state=1)
mod2.fit(X_scaled,y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
pred_val2 = mod2.predict(X_scaled_val)
pd.crosstab(y_val,pred_val2, colnames= ['pred_val2'])
# Out:
# pred_val2      0.0  1.0
# CurMet_t7_t30
# 0.0            342   34
# 1.0             27  133

# %%
pred_train2 = mod2.predict(X_scaled)
pd.crosstab(y_train,pred_train2, colnames= ['pred_rtain2'])
# Out:
# pred_rtain2     0.0  1.0
# CurMet_t7_t30
# 0.0            1487    0
# 1.0               0  653

# %%
model_dict = {'model': "Decision Tree"}
dataset_dict = {'dataset': "Train"}
models_list = models_list.append({**dataset_dict, **model_dict, **classificationMetrics(y_val, pred_val2)}, ignore_index=True)
##
model_dict = {'model': "Decision Tree"}
dataset_dict = {'dataset': "Validation"}
models_list = models_list.append({**dataset_dict, **model_dict, **classificationMetrics(y_train, pred_train2)}, ignore_index=True)
##
models_list
# Out:
#         AUC  Accuracy      Log-loss  Precision    Recall     dataset  \
# 0  0.866622  0.908582  3.157479e+00   0.917293  0.762500       Train
# 1  0.891008  0.928505  2.469368e+00   0.964684  0.794793  Validation
# 2  0.870412  0.886194  3.930770e+00   0.796407  0.831250       Train
# 3  1.000000  1.000000  9.992007e-16   1.000000  1.000000  Validation
#
#    f1-score                model
# 0  0.832765  Logistic Regression
# 1  0.871537  Logistic Regression
# 2  0.813456        Decision Tree
# 3  1.000000        Decision Tree

# %% [markdown]
# ### Random Forest

# %%
mod3 = RandomForestClassifier(random_state=1, max_depth= 3,n_jobs= 50)
mod3.fit(X_scaled,y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_jobs=50, random_state=1)

# %%
pred_train3 = mod3.predict(X_scaled)
pd.crosstab(y_train,pred_train3, colnames= ['pred_rtain3'])
# Out:
# pred_rtain3     0.0  1.0
# CurMet_t7_t30
# 0.0            1486    1
# 1.0             192  461

# %%
pred_val3 = mod3.predict(X_scaled_val)
pd.crosstab(y_val, pred_val3, colnames= ['pred_val3'])
# Out:
# pred_val3      0.0  1.0
# CurMet_t7_t30
# 0.0            375    1
# 1.0             48  112

# %%
model_dict = {'model': "RandomForest"}
dataset_dict = {'dataset': "Train"}
models_list = models_list.append({**dataset_dict, **model_dict, **classificationMetrics(y_val, pred_val3)}, ignore_index=True)
##
model_dict = {'model': "RandomForest"}
dataset_dict = {'dataset': "Validation"}
models_list = models_list.append({**dataset_dict, **model_dict, **classificationMetrics(y_train, pred_train3)}, ignore_index=True)
##
models_list
# Out:
#         AUC  Accuracy      Log-loss  Precision    Recall     dataset  \
# 0  0.866622  0.908582  3.157479e+00   0.917293  0.762500       Train
# 1  0.891008  0.928505  2.469368e+00   0.964684  0.794793  Validation
# 2  0.870412  0.886194  3.930770e+00   0.796407  0.831250       Train
# 3  1.000000  1.000000  9.992007e-16   1.000000  1.000000  Validation
# 4  0.848670  0.908582  3.157464e+00   0.991150  0.700000       Train
# 5  0.852650  0.909813  3.114946e+00   0.997835  0.705972  Validation
#
#    f1-score                model
# 0  0.832765  Logistic Regression
# 1  0.871537  Logistic Regression
# 2  0.813456        Decision Tree
# 3  1.000000        Decision Tree
# 4  0.820513         RandomForest
# 5  0.826906         RandomForest

# %% [markdown]
# ### Adaptive Boosting (ADABoost)

# %%
mod4 = AdaBoostClassifier(random_state=1)
mod4.fit(X_scaled,y_train)
# Out:
# AdaBoostClassifier(random_state=1)

# %%
pred_train4 = mod4.predict(X_scaled)
pd.crosstab(y_train,pred_train4, colnames= ['pred_rtain4'])
# Out:
# pred_rtain4     0.0  1.0
# CurMet_t7_t30
# 0.0            1450   37
# 1.0             115  538

# %%
pred_val4 = mod4.predict(X_scaled_val)
pd.crosstab(y_val, pred_val4, colnames= ['pred_val4'])
# Out:
# pred_val4      0.0  1.0
# CurMet_t7_t30
# 0.0            364   12
# 1.0             37  123

# %%
model_dict = {'model': "ADABoost"}
dataset_dict = {'dataset': "Train"}
models_list = models_list.append({**dataset_dict, **model_dict, **classificationMetrics(y_val, pred_val4)}, ignore_index=True)
##
model_dict = {'model': "ADABoost"}
dataset_dict = {'dataset': "Validation"}
models_list = models_list.append({**dataset_dict, **model_dict, **classificationMetrics(y_train, pred_train4)}, ignore_index=True)
##
models_list
# Out:
#         AUC  Accuracy      Log-loss  Precision    Recall     dataset  \
# 0  0.866622  0.908582  3.157479e+00   0.917293  0.762500       Train
# 1  0.891008  0.928505  2.469368e+00   0.964684  0.794793  Validation
# 2  0.870412  0.886194  3.930770e+00   0.796407  0.831250       Train
# 3  1.000000  1.000000  9.992007e-16   1.000000  1.000000  Validation
# 4  0.848670  0.908582  3.157464e+00   0.991150  0.700000       Train
# 5  0.852650  0.909813  3.114946e+00   0.997835  0.705972  Validation
# 6  0.868418  0.908582  3.157481e+00   0.911111  0.768750       Train
# 7  0.899504  0.928972  2.453235e+00   0.935652  0.823890  Validation
#
#    f1-score                model
# 0  0.832765  Logistic Regression
# 1  0.871537  Logistic Regression
# 2  0.813456        Decision Tree
# 3  1.000000        Decision Tree
# 4  0.820513         RandomForest
# 5  0.826906         RandomForest
# 6  0.833898             ADABoost
# 7  0.876221             ADABoost

# %% [markdown]
# ### Gradient Boosting Machine (GBM)

# %%
mod5 = GradientBoostingClassifier(random_state=1)
mod5.fit(X_scaled,y_train)
# Out:
# GradientBoostingClassifier(random_state=1)

# %%
pred_val5 = mod5.predict(X_scaled_val)
pd.crosstab(y_val, pred_val5, colnames= ['pred_val5'])
# Out:
# pred_val5      0.0  1.0
# CurMet_t7_t30
# 0.0            369    7
# 1.0             42  118

# %%
pred_train5 = mod5.predict(X_scaled)
pd.crosstab(y_train, pred_train5, colnames= ['pred_rtain5'])
# Out:
# pred_rtain5     0.0  1.0
# CurMet_t7_t30
# 0.0            1485    2
# 1.0             105  548

# %%
model_dict = {'model': "GBM"}
dataset_dict = {'dataset': "Train"}
models_list = models_list.append({**dataset_dict, **model_dict, **classificationMetrics(y_val, pred_val5)}, ignore_index=True)
##
model_dict = {'model': "GBM"}
dataset_dict = {'dataset': "Validation"}
models_list = models_list.append({**dataset_dict, **model_dict, **classificationMetrics(y_train, pred_train5)}, ignore_index=True)
##
models_list
# Out:
#         AUC  Accuracy      Log-loss  Precision    Recall     dataset  \
# 0  0.866622  0.908582  3.157479e+00   0.917293  0.762500       Train
# 1  0.891008  0.928505  2.469368e+00   0.964684  0.794793  Validation
# 2  0.870412  0.886194  3.930770e+00   0.796407  0.831250       Train
# 3  1.000000  1.000000  9.992007e-16   1.000000  1.000000  Validation
# 4  0.848670  0.908582  3.157464e+00   0.991150  0.700000       Train
# 5  0.852650  0.909813  3.114946e+00   0.997835  0.705972  Validation
# 6  0.868418  0.908582  3.157481e+00   0.911111  0.768750       Train
# 7  0.899504  0.928972  2.453235e+00   0.935652  0.823890  Validation
# 8  0.859441  0.908582  3.157473e+00   0.944000  0.737500       Train
# 9  0.918929  0.950000  1.726940e+00   0.996364  0.839204  Validation
#
#    f1-score                model
# 0  0.832765  Logistic Regression
# 1  0.871537  Logistic Regression
# 2  0.813456        Decision Tree
# 3  1.000000        Decision Tree
# 4  0.820513         RandomForest
# 5  0.826906         RandomForest
# 6  0.833898             ADABoost
# 7  0.876221             ADABoost
# 8  0.828070                  GBM
# 9  0.911056                  GBM

# %% [markdown]
# ### Support Vector Machine (SVM)

# %%
mod6 = SVC(probability=True)
mod6.fit(X_scaled,y_train)
# Out:
# SVC(probability=True)

# %%
pred_train6 = mod6.predict(X_scaled)
pd.crosstab(y_train,pred_train6, colnames= ['pred_rtain6'])
# Out:
# pred_rtain6     0.0  1.0
# CurMet_t7_t30
# 0.0            1485    2
# 1.0             154  499

# %%
pred_val6 = mod6.predict(X_scaled_val)
pd.crosstab(y_val, pred_val6, colnames= ['pred_val6'])
# Out:
# pred_val6      0.0  1.0
# CurMet_t7_t30
# 0.0            373    3
# 1.0             46  114

# %%
model_dict = {'model': "SVM"}
dataset_dict = {'dataset': "Train"}
models_list = models_list.append({**dataset_dict, **model_dict, **classificationMetrics(y_val, pred_val6)}, ignore_index=True)
##
model_dict = {'model': "SVM"}
dataset_dict = {'dataset': "Validation"}
models_list = models_list.append({**dataset_dict, **model_dict, **classificationMetrics(y_train, pred_train6)}, ignore_index=True)
##
models_list
# Out:
#          AUC  Accuracy      Log-loss  Precision    Recall     dataset  \
# 0   0.866622  0.908582  3.157479e+00   0.917293  0.762500       Train
# 1   0.891008  0.928505  2.469368e+00   0.964684  0.794793  Validation
# 2   0.870412  0.886194  3.930770e+00   0.796407  0.831250       Train
# 3   1.000000  1.000000  9.992007e-16   1.000000  1.000000  Validation
# 4   0.848670  0.908582  3.157464e+00   0.991150  0.700000       Train
# 5   0.852650  0.909813  3.114946e+00   0.997835  0.705972  Validation
# 6   0.868418  0.908582  3.157481e+00   0.911111  0.768750       Train
# 7   0.899504  0.928972  2.453235e+00   0.935652  0.823890  Validation
# 8   0.859441  0.908582  3.157473e+00   0.944000  0.737500       Train
# 9   0.918929  0.950000  1.726940e+00   0.996364  0.839204  Validation
# 10  0.852261  0.908582  3.157467e+00   0.974359  0.712500       Train
# 11  0.881410  0.927103  2.517781e+00   0.996008  0.764165  Validation
#
#     f1-score                model
# 0   0.832765  Logistic Regression
# 1   0.871537  Logistic Regression
# 2   0.813456        Decision Tree
# 3   1.000000        Decision Tree
# 4   0.820513         RandomForest
# 5   0.826906         RandomForest
# 6   0.833898             ADABoost
# 7   0.876221             ADABoost
# 8   0.828070                  GBM
# 9   0.911056                  GBM
# 10  0.823105                  SVM
# 11  0.864818                  SVM

# %% [markdown]
# ## Model Selection

# %% [markdown]
# In order to minimize false negative, select model according to maximize Recall metric

# %%
models_list.sort_values(['dataset','Recall'],ascending=False)
# Out:
#          AUC  Accuracy      Log-loss  Precision    Recall     dataset  \
# 3   1.000000  1.000000  9.992007e-16   1.000000  1.000000  Validation
# 9   0.918929  0.950000  1.726940e+00   0.996364  0.839204  Validation
# 7   0.899504  0.928972  2.453235e+00   0.935652  0.823890  Validation
# 1   0.891008  0.928505  2.469368e+00   0.964684  0.794793  Validation
# 11  0.881410  0.927103  2.517781e+00   0.996008  0.764165  Validation
# 5   0.852650  0.909813  3.114946e+00   0.997835  0.705972  Validation
# 2   0.870412  0.886194  3.930770e+00   0.796407  0.831250       Train
# 6   0.868418  0.908582  3.157481e+00   0.911111  0.768750       Train
# 0   0.866622  0.908582  3.157479e+00   0.917293  0.762500       Train
# 8   0.859441  0.908582  3.157473e+00   0.944000  0.737500       Train
# 10  0.852261  0.908582  3.157467e+00   0.974359  0.712500       Train
# 4   0.848670  0.908582  3.157464e+00   0.991150  0.700000       Train
#
#     f1-score                model
# 3   1.000000        Decision Tree
# 9   0.911056                  GBM
# 7   0.876221             ADABoost
# 1   0.871537  Logistic Regression
# 11  0.864818                  SVM
# 5   0.826906         RandomForest
# 2   0.813456        Decision Tree
# 6   0.833898             ADABoost
# 0   0.832765  Logistic Regression
# 8   0.828070                  GBM
# 10  0.823105                  SVM
# 4   0.820513         RandomForest

# %%
models_list.sort_values(['dataset','AUC'],ascending=False)
# Out:
#          AUC  Accuracy      Log-loss  Precision    Recall     dataset  \
# 3   1.000000  1.000000  9.992007e-16   1.000000  1.000000  Validation
# 9   0.918929  0.950000  1.726940e+00   0.996364  0.839204  Validation
# 7   0.899504  0.928972  2.453235e+00   0.935652  0.823890  Validation
# 1   0.891008  0.928505  2.469368e+00   0.964684  0.794793  Validation
# 11  0.881410  0.927103  2.517781e+00   0.996008  0.764165  Validation
# 5   0.852650  0.909813  3.114946e+00   0.997835  0.705972  Validation
# 2   0.870412  0.886194  3.930770e+00   0.796407  0.831250       Train
# 6   0.868418  0.908582  3.157481e+00   0.911111  0.768750       Train
# 0   0.866622  0.908582  3.157479e+00   0.917293  0.762500       Train
# 8   0.859441  0.908582  3.157473e+00   0.944000  0.737500       Train
# 10  0.852261  0.908582  3.157467e+00   0.974359  0.712500       Train
# 4   0.848670  0.908582  3.157464e+00   0.991150  0.700000       Train
#
#     f1-score                model
# 3   1.000000        Decision Tree
# 9   0.911056                  GBM
# 7   0.876221             ADABoost
# 1   0.871537  Logistic Regression
# 11  0.864818                  SVM
# 5   0.826906         RandomForest
# 2   0.813456        Decision Tree
# 6   0.833898             ADABoost
# 0   0.832765  Logistic Regression
# 8   0.828070                  GBM
# 10  0.823105                  SVM
# 4   0.820513         RandomForest
